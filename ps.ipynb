# %%
n=5
for i in range(1,n+1,1):
    for j in range(1,n-i+1,1):
        print(" ",end="")
    y=1
    for k in range(1,i+1,1):
        print(y,end="")
        y+=1
    y=i-1
    for l in range(1,i-1+1,1):
        print(y,end="")
        y-=1
    print()
# Out:
#     1
#    121
#   12321
#  1234321
# 123454321

# %%
n=4
for i in range(1,n+1,1):
    for j in range(1,n-i+1,1):
        print(" ",end="")
    y=i
    for l in range(1,i+1,1):
        print(y,end="")
        y-=1
    y=2
    for k in range(1,i-1+1,1):
        print(y,end='')
        y+=1
    print()
# Out:
#    1
#   212
#  32123
# 4321234

# %%
n=5
for i in range(1,n+1,1):
    y=1
    for j in range(1,i+1-1,1):
        print(y,end='')
        y+=1
    y=i
    for k in range(1,(n-i)+(n-i)+1+1,1):
        print(y,end='')
    y=i-1
    for l in range(1,i-1+1,1):
        print(y,end='')
        y-=1
    
    print()
n-=1
for i in range(1,n+1,1):
    y=1
    for m in range(1,n-i+1,1):
        print(y,end='')
        y+=1
    y=i
    for n in range(1,(i*2)-1+1,1):
        print(y,end='')
        y-=1
    for o in range(1,n-i+1,1)
# Out:
#   Cell In[18], line 16
#     for i in range(1,n+1,1):
#                             ^
# _IncompleteInputError: incomplete input

# %%
arr=[9,19,20,3,43,2,33,3]
for i in range(len(arr)):
    mini=i
    for j in range(i,len(arr)):
        if arr[mini]>arr[j]:
            mini=j
    arr[mini],arr[i]=arr[i],arr[mini]
print(arr)
# Out:
# [2, 3, 3, 9, 19, 20, 33, 43]

# %%
arr=[9,19,20,3,43,2,33,3]
for i in range(len(arr)):
    swap=False
    for j in range(len(arr)-i-1):
        if arr[j]>arr[j+1]:
            swap=True
            arr[j],arr[j+1]=arr[j+1],arr[j]
    if not swap:
        break
print(arr)
# Out:
# [2, 3, 3, 9, 19, 20, 33, 43]

# %%
arr=[9,19,20,3,43,2,33,3]
for i in range(1,len(arr)):
    j=i
    while(j>0 and arr[j]<arr[j-1]):
        arr[j],arr[j-1]=arr[j-1],arr[j]
        j-=1
    
print(arr)
# Out:
# [2, 3, 3, 9, 19, 20, 33, 43]

# %%
arr=[9,19,20,3,43,2,33,3]
def quick(arr,low,high):
    if low<high:
        p_loc=partition(arr,low,high)
        quick(arr,low,p_loc-1)
        quick(arr,p_loc+1,high)
def partition(arr,low,high):
    p=arr[high]
    i=low-1
    for j in range(low,high):
        if arr[j]<=p:
            i+=1
            arr[i],arr[j]=arr[j],arr[i]
    arr[i+1],arr[high]=arr[high],arr[i+1]
    return i+1
quick(arr,0,len(arr)-1)
print(arr)
# Out:
# [2, 3, 3, 9, 19, 20, 33, 43]

# %%
arr=[9,19,20,3,43,2,33,3]
def mergesort(arr):
    if len(arr)==1:
        return arr
    n=len(arr)//2
    
    leftarr=arr[:n]
    rightarr=arr[n:]
    left_sorted=mergesort(leftarr)
    right_sorted=mergesort(rightarr)
    return merge(left_sorted,right_sorted)
def merge(l,r):
    i=0
    j=0
    new=[]
    while(i<len(l) and j<len(r)):
        if l[i]<=r[j]:
            new.append(l[i])
            i+=1
        else:
            new.append(r[j])
            j+=1
    while(i<len(l)):
        new.append(l[i])
        i+=1
    while(j<len(r)):
        new.append(r[j])
        j+=1
    return new
print(mergesort(arr))
# Out:
# [2, 3, 3, 9, 19, 20, 33, 43]

# %%
arr=[9,8,7,65,4,3,2,1]
def quicksort(arr,low,high):
    if low<high:
        p_loc=partition(arr,low,high)
        quicksort(arr,low,p_loc-1)
        quicksort(arr,p_loc+1,high)
def partition(arr,low,high):
    piv=arr[high]
    i=low-1
    for j in range(low,high):
        if arr[j]<=piv:
            i+=1
            arr[j],arr[i]=arr[i],arr[j]
    arr[i+1],arr[high]=arr[high],arr[i+1]
    return i+1
print("Before",arr)
quicksort(arr,0,len(arr)-1)
print("After:",arr)
# Out:
# Before [9, 8, 7, 65, 4, 3, 2, 1]
# After: [1, 2, 3, 4, 7, 8, 9, 65]

# %% [markdown]
# ARRAY EASY

# %%
nums = [3, 3, 0, 99, -40]
max=nums[0]
for i in range(1,len(nums)):
    if nums[i]>max:
        max=nums[i]
print(max)
# Out:
# 99

# %%
nums = [8, 8, 7, 6, 5]
maxi = float('-inf')
secmax=float('-inf')
for i in range(len(nums)):
    if nums[i]>maxi:
        secmax=maxi
        maxi=nums[i]
    elif nums[i]<maxi and nums[i]>secmax:
        secmax=nums[i]
print(maxi)
print(secmax if secmax!=float('-inf') else -1)
# Out:
# 8
# 7

# %%
nums = [1, 2, 1, 4, 5]
flag=True
for i in range(1,len(nums)):
    if nums[i-1]>nums[i]:
        flag=False
        break
if flag:
    print( "true")
else:
    print("false")
# Out:
# false

# %%
nums = [2,1,3,4]
flag=True
mini=nums.index(min(nums))
for i in range(mini+1,len(nums)):
    if nums[i-1]>nums[i]:
        flag=False
        break
for i in range(1,mini):
      if nums[i-1]>nums[i]:
        flag=False
        break
if flag:
    print("True")
else:
    print("false")
# Out:
# True

# %%
nums = [0,0,1,1,1,2,2,3,3,4]
i=0
j=1
while(j<len(nums)):
    if nums[i]!=nums[j]:
       i+=1
       nums[i]=nums[j]
    j+=1
print(nums[:i+1])
print(i+1)
# Out:
# [0, 1, 2, 3, 4]
# 5

# %%
nums = [1,2,3,4,5,6,7]
k = 3
num=k*[0]
nums[:]=num+nums
for i in range(k):
    nums[i],nums[(k-i)*-1]=nums[-1*(k-i)],nums[i]
# Out:
# [5, 6, 7, 1, 2, 3, 4]

# %%
nums = [1,2,3,4,5,6,7]
k=3

nums[:]=nums[1:]+nums[:1]
print(nums)
# Out:
# [2, 3, 4, 5, 6, 7, 1]

# %%
nums1 = [ 4, 6, 7, 9, 9]
nums2 = [1, 5, 7, 8, 8]


i=0
j=0
new=[]
while(i<len(nums1) and j<len(nums2)):
    if nums1[i]<nums2[j]:
        if not new or new[-1] != nums1[i]:
            new.append(nums1[i])
            i+=1
        else:
            i+=1
    elif nums1[i]>nums2[j]:
        if not new or new[-1] != nums2[j]:
            new.append(nums2[j])
            j+=1
        else:
            j+=1
    else:
        if not new or new[-1] != nums1[i]:
            new.append(nums1[i])
            i+=1
            j+=1
        else:
            i+=1
            j+=1
while(i<len(nums1)):
    if not new or new[-1] != nums1[i]:
        new.append(nums1[i])
        i+=1
    else:
        i+=1
while(j<len(nums2)):
    if not new or new[-1] != nums2[j]:
        new.append(nums2[j])
        j+=1
    else:
        j+=1
print(new)
# Out:
# [1, 4, 5, 6, 7, 8, 9]

# %%
nums = [1, 3, 6, 4, 2, 5]
arr=[x for x in range(len(nums)+1)]
nums=set(nums)
for i in arr:
    if i not in nums:
        print(i)
        break
# Out:
# 0

# %%
nums = [0, 1, 2, 4, 5, 6]
n=len(nums)
sum1=(n*(n+1))//2
acsum=sum(nums)
print(sum1-acsum)
# Out:
# 3

# %%
nums = [0, 1, 2, 4, 5, 6]
xor_all = 0
n = len(nums)
        
        # XOR all array elements and indices 0 to n
for i in range(n):
    print(i,nums[i])
    print('i cap nums[i]',i^nums[i])
    xor_all ^= i ^ nums[i]
    print('xor_all',xor_all)
            
print(xor_all ^ n)
# Out:
# 0 0
# i cap nums[i] 0
# xor_all 0
# 1 1
# i cap nums[i] 0
# xor_all 0
# 2 2
# i cap nums[i] 0
# xor_all 0
# 3 4
# i cap nums[i] 7
# xor_all 7
# 4 5
# i cap nums[i] 1
# xor_all 6
# 5 6
# i cap nums[i] 3
# xor_all 5
# 3

# %%
nums = [1,0,1,1,0,1]
count=0
maxi=0
for i in range(len(nums)):
    if nums[i]==1:
        count+=1
        maxi=max(maxi,count)
    else:
        count=0
print(maxi)
# Out:
# 2

# %%
nums = [0]
i=0
j=0
while(j<len(nums)):
    if i==j:
        j+=1
        continue
    if nums[i]!=0:
        i+=1
        continue
    if nums[j]==0:
        j+=1
        continue
    if nums[j]!=0:
        nums[i],nums[j]=nums[j],nums[i]
print(nums)
# Out:
# [0]

# %%
nums = [1, 3, 10, 3, 5, 1, 5]
xor=0
for i in nums:
    xor^=i
print(xor)
# Out:
# 10

# %%
nums = [-1,1,1]
k=1
left =0
tar=0
maxi=0
for right in range(len(nums)):
    tar+=nums[right]
    
    while tar>=k:
        if tar==k:
            maxi=max(maxi,right-left+1)
            print(maxi)
        tar-=nums[left]
        left+=1
print(maxi)
# Out:
# 3
# 3
# 3

# %%
nums = [1]
k = 0
left =0
tar=0
maxi=0
for right in range(len(nums)):
    tar+=nums[right]
    while tar>=k:
        if tar==k:
            maxi+=1
        tar-=nums[left]
        left+=1
print(maxi)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 11
#       9         if tar==k:
#      10             maxi+=1
# ---> 11         tar-=nums[left]
#      12         left+=1
#      13 print(maxi)
#
# IndexError: list index out of range

# %%
nums = [0,1,2,2,3,0,4,2]
val = 2
# Out:
# 1 0 [0, 1, 2, 2, 3, 0, 4, 2]
# 2 1 [0, 1, 2, 2, 3, 0, 4, 2]
# 3 4 [0, 1, 3, 2, 2, 0, 4, 2]
# 4 5 [0, 1, 3, 0, 2, 2, 4, 2]
# 5 6 [0, 1, 3, 0, 4, 2, 2, 2]
# [0, 1, 3, 0, 4, 2, 2, 2] 5
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
nums = [-4,-1,0,3,10]
arr=[0]*len(nums)
left,right=0,len(nums)-1
pos=len(nums)-1
while left<=right:
    if abs(nums[left])>abs(nums[right]):
        arr[pos]=nums[left]**2
        left+=1
    else:
        arr[pos]=nums[right]**2
        right-=1
    pos-=1
print(arr)
# Out:
# [0, 1, 9, 16, 100]

# %%
s = "abcd"
t = "abcde"
xor1=0
xor2=0
for i in t:
    xor1^=ord(i)
for j in s:
    xor2^=ord(j)
print(chr(xor1^xor2))
# Out:
# 4
# e

# %%
nums = [3,0,1]
xor=0
for i in range(len(nums)):
    xor^=i^nums[i]
xor^=len(nums)
print(xor)
# Out:
# 2

# %%
nums = [10, 5, 2, 7, 1,-10]
k=15
di={}
s=0
maxi=0
for i in range(len(nums)):
    s+=nums[i]
    if s==k:
        maxi=max(maxi,i+1)
    else:
        if s-k in di:
            maxi=max(maxi,i-di[s-k])
        else:
            di[s]=i
print(maxi)
# Out:
# 6

# %%
nums = [1, 6, 2, 10, 3]
target = 7
numsi=[(num,idx) for idx,num in enumerate(nums)]
numsi.sort(key=lambda x:x[0])
i=0
j=len(nums)-1
while(i<=j):
    if numsi[i][0]+numsi[j][0]==target:
        print([numsi[i][1],numsi[j][1]])
        break
    elif numsi[i][0]+numsi[j][0]>target:
        j-=1
    else:
        i+=1
# Out:
# [0, 1]

# %%
nums = [1, 0, 2, 1, 0]
low=0
high=len(nums)-1
mid=0
while(mid<=high):
    print(mid,low,high)
    if nums[mid]==0:
        nums[mid],nums[low]=nums[low],nums[mid]
        mid+=1
        low+=1
    elif nums[mid]==1:
        mid+=1
    else:
        nums[mid],nums[high]=nums[high],nums[mid]
        high-=1
print(nums)
# Out:
# 0 0 4
# 1 0 4
# 2 1 4
# 2 1 3
# 3 2 3
# [0, 0, 1, 1, 2]

# %%
nums = [7, 0, 0, 1, 7, 7, 2, 7, 7]
count=0
for i in range(len(nums)):
    if count==0:
        el=nums[i]
        count+=1
    elif nums[i]==el:
        count+=1
    else:
        count-=1
count=0
for i in nums:
    if i ==el:
        count+=1
if count>len(nums)/2:
    print(el)
# Out:
# 7

# %%
nums = [-2, -3, -7, -2, -10, -4]
sum=0
maxi=float('-inf')
for i in range(len(nums)):
    if sum<0:
        sum=nums[i]
    else:
        sum+=nums[i]
    maxi=max(sum,maxi)
print(maxi)
# Out:
# -2

# %%
nums=[0,2,1,2,0,1,2,1,0]
low=0
high=len(nums)-1
mid=0
while(mid<=high):
    print(mid,high)
    if nums[mid]==0:
        nums[low],nums[mid]=nums[mid],nums[low]
        low+=1
        mid+=1
    elif nums[mid]==1:
        mid+=1
    else:
        nums[high],nums[mid]=nums[mid],nums[high]
        high-=1
print(nums)
# Out:
# 0 8
# 1 8
# 1 7
# 2 7
# 3 7
# 3 6
# 4 6
# 5 6
# 6 6
# [0, 0, 0, 1, 1, 1, 2, 2, 2]

# %%
nums1 =[4,5,6,0,0,0]
m =3
nums2 =[1,2,3]
n =3
i=m-1
j=n-1
k=m+n-1
while(i>=0 and j>=0 and k>=0):
    if nums1[i]<=nums2[j]:
        nums1[k]=nums2[j]
        j-=1
    else:
        nums1[k]=nums1[i]
        i-=1
    k-=1
while(i>=0 and k>=0):
    nums1[k]=nums1[i]
    i-=1
    k-=1
while(j>=0 and k>=0):
    print(i,j,k)
    nums1[k]=nums2[j]
    j-=1
    k-=1
print(nums1)
# Out:
# -1 2 2
# -1 1 1
# -1 0 0
# [1, 2, 3, 4, 5, 6]

# %%
arr= [7,6,4,3,1]
i=len(arr)-1
j=i-1
maxi=0
while(j>=0):
    if arr[i]<arr[j]:
        i=j
        j-=1
    else:
        maxi=max(maxi,arr[i]-arr[j])
        j-=1
print(maxi)
# Out:
# 0

# %%
nums = [3,1,-2,-5,2,-4]
n=len(nums)
ls=[0]*n
i=0
j=1
for k in nums:
    if k>0:
        ls[i]=k
        i+=2
    else:
        ls[j]=k
        j+=2
print(ls)
# Out:
# [3, -2, 1, -5, 2, -4]

# %%
nums=[3,2,1]
for i in range(len(nums)-1,0,-1):
    if nums[i]>nums[i-1]:
        ind=i-1
        print(ind)
        break
else:
    print(nums[::-1])
for j in range(len(nums)-1,ind,-1):

    if nums[j]>nums[ind]:
        nums[j],nums[ind]=nums[ind],nums[j]
        print(nums)
        break
nums[:]=nums[:ind+1]+nums[ind+1:][::-1]
print(nums)
# Out:
# [1, 2, 3]
# [3, 1, 2]
# [2, 1, 3]

# %%
nums = [-3, 4, 5, 1, -4, -5]
maxi=nums[len(nums)-1]
ls=[]
for i in range(len(nums)-1,-1,-1):
    if nums[i]>=maxi:
        maxi=nums[i]
        ls.append(nums[i])
    else:
        continue
print(ls[::-1])
# Out:
# [5, 1, -4, -5]

# %%
nums = [1]
k = 0
left =0
tar=0
maxi=0
for right in range(len(nums)):
    tar+=nums[right]
    while tar>=k and left<=right:
        if tar==k:
            maxi+=1
        tar-=nums[left]
        left+=1
print(maxi)
# Out:
# 0

# %%
nums = [-1]
ls=[nums[0]] if len(nums)!=0 else []
mls=[]
for i in range(1,len(nums)):
    print(ls,i)
    if nums[i-1]==(nums[i]-1):
        ls.append(nums[i])
    else:
        mls.append(ls)
        ls=[]
        ls.append(nums[i])
mls.append(ls)
print(mls)
for i in range(len(mls)):
    if len(mls[i])==0:
        mls=[]
    elif len(mls[i])==1:
        mls[i]=str(mls[i][0])
    else:
        mls[i]=f"{mls[i][0]}->{mls[i][-1]}"
print(mls)
# Out:
# [[-1]]
# ['-1']
